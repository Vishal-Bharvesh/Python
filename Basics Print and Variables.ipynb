# %%
print("Hello World!")
print("Python Learning Session")
print("-------")
print("By : Vishal Bharvesh")
# Out:
# Hello World!
# Python Learning Session
# -------
# By : Vishal Bharvesh

# %% [markdown]
# PYTHON  - VARIABLE type

# %%
var1=34
var2="SAM"
var3=True
var4='M'
var5=167.5
var6=1273687236487263847687368732.234234234

print( type(var1) )
print( type(var2) )
print( type(var3) )
print( type(var4) )
print( type(var5) )
print( type(var6) )

print("------------")

var7=56
print( type(var7) )
var7="SAM"
print( type(var7) )
var7=True
print( type(var7) )
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# ------------
# <class 'int'>
# <class 'str'>
# <class 'bool'>
