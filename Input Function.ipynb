# %%
#String
value = input("Entry Your Name : ")
print(type(value))

#Number int
value=int(   input("Enter Your Age : ")    )
print(type(value))

#Number float
value=float(   input("Enter Your Height : ")    )
print(type(value))
# Out:
# Entry Your Name : Vishal
# <class 'str'>
# Enter Your Age : 44
# <class 'int'>
# Enter Your Height : 175.6
# <class 'float'>
