# %% [markdown]
# Tuples : Immutable , ()

# %%
tupseq=("Python","Solidity","React","Node")

# %%
print(tupseq)
# Out:
# ('Python', 'Solidity', 'React', 'Node')

# %%
tupseq
# Out:
# ('Python', 'Solidity', 'React', 'Node')

# %%
tupseq2=("Smith",24,176.5,66.3,False)

# %%
print(tupseq2)
# Out:
# ('Smith', 24, 176.5, 66.3, False)

# %%
tupseq[3]="Node.js"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e9302ccf2d8a> in <cell line: 1>()
# ----> 1 tupseq[3]="Node.js"
#
# TypeError: 'tuple' object does not support item assignment

# %%
del tupseq[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4c0491182b62> in <cell line: 1>()
# ----> 1 del tupseq[3]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
tup1=(23,34,45)
tup2=(11,22,33)

tup3=tup1 + tup2

print(tup3)
# Out:
# (23, 34, 45, 11, 22, 33)

# %%
tup1=(23,34,45)
tup2=(11,22,33)

tup2=tup1 + tup2

print(tup2)
# Out:
# (23, 34, 45, 11, 22, 33)

# %%
len(tup2)
# Out:
# 6

# %%
max(tup2)
# Out:
# 45

# %%
min(tup2)
# Out:
# 11

# %%
tup2.sort
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f4d6866dc994> in <cell line: 1>()
# ----> 1 tup2.sort
#
# AttributeError: 'tuple' object has no attribute 'sort'
